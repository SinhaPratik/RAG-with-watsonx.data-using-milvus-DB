# %% [markdown]
# ## This notebook walks through RAG approach to demonstrate the integration of watsonx.ai and watsonx.data platform through MILVUS.
# The following steps:
#
# 1- Loading data from documents into watsonx.data
#
# 2- Integrating milvus vector database to watsonx.data and loading vector embeddings to milvus
#
# 3- Querying milvus and invoking LLM to get results

# %% [markdown]
# #### Install required libraries and load documents

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: ipython-sql==0.4.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: sqlalchemy==1.4.46 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.4.46)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: grpcio==1.60.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.60.0)
# Requirement already satisfied: pymilvus in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.4.3)
# Requirement already satisfied: milvus in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (2.3.8)
# Requirement already satisfied: sentence_transformers in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: ibm-cloud-sdk-core in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (3.20.1)
# Requirement already satisfied: langchain in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.2.3)
# Requirement already satisfied: pypdf in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (4.2.0)
# Requirement already satisfied: ibm-watson-machine-learning in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (1.0.359)
# Requirement already satisfied: pandas==2.1.4 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (2.1.4)
# Requirement already satisfied: streamlit in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (1.35.0)
# Requirement already satisfied: langchain_community in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (0.2.4)
# Requirement already satisfied: PyPDF2 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (3.0.1)
# Requirement already satisfied: pyhive[presto] in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: prettytable<1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: ipython>=1.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython-sql==0.4.1->-r requirements.txt (line 1)) (8.20.0)
# Requirement already satisfied: sqlparse in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: six in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython-sql==0.4.1->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pandas==2.1.4->-r requirements.txt (line 13)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pandas==2.1.4->-r requirements.txt (line 13)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pandas==2.1.4->-r requirements.txt (line 13)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pandas==2.1.4->-r requirements.txt (line 13)) (2024.1)
# Requirement already satisfied: future in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pyhive[presto]->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: requests>=1.0.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pyhive[presto]->-r requirements.txt (line 3)) (2.32.2)
# Requirement already satisfied: setuptools>=67 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 6)) (69.5.1)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 6)) (4.25.3)
# Requirement already satisfied: environs<=9.5.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 6)) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 6)) (5.10.0)
# Requirement already satisfied: milvus-lite<2.5.0,>=2.4.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pymilvus->-r requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 8)) (4.41.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 8)) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 8)) (2.3.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 8)) (0.23.3)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from sentence_transformers->-r requirements.txt (line 8)) (10.3.0)
# Requirement already satisfied: urllib3<3.0.0,>=2.1.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-cloud-sdk-core->-r requirements.txt (line 9)) (2.1.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-cloud-sdk-core->-r requirements.txt (line 9)) (2.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 10)) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 10)) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 10)) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 10)) (0.2.5)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 10)) (0.2.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 10)) (0.1.77)
# Requirement already satisfied: pydantic<3,>=1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 10)) (2.7.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain->-r requirements.txt (line 10)) (8.3.0)
# Requirement already satisfied: typing_extensions>=4.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pypdf->-r requirements.txt (line 11)) (4.11.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-watson-machine-learning->-r requirements.txt (line 12)) (2024.6.2)
# Requirement already satisfied: lomond in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-watson-machine-learning->-r requirements.txt (line 12)) (0.3.3)
# Requirement already satisfied: tabulate in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-watson-machine-learning->-r requirements.txt (line 12)) (0.9.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-watson-machine-learning->-r requirements.txt (line 12)) (23.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-watson-machine-learning->-r requirements.txt (line 12)) (2.13.4)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-watson-machine-learning->-r requirements.txt (line 12)) (7.1.0)
# Requirement already satisfied: altair<6,>=4.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (8.1.7)
# Requirement already satisfied: pyarrow>=7.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (16.1.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (13.7.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 14)) (6.3.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain_community->-r requirements.txt (line 15)) (0.6.7)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 10)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 10)) (1.9.4)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (4.19.2)
# Requirement already satisfied: toolz in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 15)) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 15)) (0.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 14)) (4.0.11)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r requirements.txt (line 8)) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence_transformers->-r requirements.txt (line 8)) (2024.6.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.4 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning->-r requirements.txt (line 12)) (2.13.4)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.4 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning->-r requirements.txt (line 12)) (2.13.4)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning->-r requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langchain-core<0.3.0,>=0.2.0->langchain->-r requirements.txt (line 10)) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain->-r requirements.txt (line 10)) (3.10.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 10)) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from requests>=1.0.0->pyhive[presto]->-r requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from requests>=1.0.0->pyhive[presto]->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 8)) (1.12.1)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers->-r requirements.txt (line 8)) (3.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers->-r requirements.txt (line 8)) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers->-r requirements.txt (line 8)) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers->-r requirements.txt (line 8)) (0.4.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from importlib-metadata->ibm-watson-machine-learning->-r requirements.txt (line 12)) (3.19.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from scikit-learn->sentence_transformers->-r requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from scikit-learn->sentence_transformers->-r requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 14)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain->-r requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 14)) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 14)) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 15)) (1.0.0)
# Requirement already satisfied: executing in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql==0.4.1->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/anaconda3/envs/milvus_workshop/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence_transformers->-r requirements.txt (line 8)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Restart kernel after installing the packages

# %%
from langchain_community.document_loaders.pdf import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
import PyPDF2
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
pdf_files=['/Users/pratiksinha/Desktop/workshop/RAG with watsonx.data using milvus/pdf/IBM Watsonx.Data [TechTalks].pdf',
          '/Users/pratiksinha/Desktop/workshop/RAG with watsonx.data using milvus/pdf/DB2 and DB2 Warehouse on Cloud [TechTalks].pdf',
          '/Users/pratiksinha/Desktop/workshop/RAG with watsonx.data using milvus/pdf/IBM watsonx.data Milvus Vector Database Competitive - Mar 2024 Final.pdf',
          '/Users/pratiksinha/Desktop/workshop/RAG with watsonx.data using milvus/pdf/watsonx_Value, Differentiators and Capabilities.pdf']

# %%
all_data=''
if pdf_files:
    for pdf in pdf_files:
        pdf_reader = PyPDF2.PdfReader(pdf)
        # Extract text from each page
        for page in pdf_reader.pages:
            text = page.extract_text()
            all_data += text
all_data = all_data.replace("'", "''").replace("%", "%%").replace("\n"," ")

# %%
len(all_data)
# Out:
# 93671

# %% [markdown]
# ## Load document into watsonx.data

# %% [markdown]
# #### Connect to watsonx.data

# %%
import ssl
import urllib3
import os
from sqlalchemy import create_engine
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning) # disable https warning

LH_HOST_NAME='useast.services.cloud.techzone.ibm.com'
LH_PORT=33027
LH_USER='ibmlhadmin'
LH_PW='password'
LH_CATALOG='tpch'
LH_SCHEMA='tiny'

quick_engine = create_engine(
   f"presto://{LH_USER}:{LH_PW}@{LH_HOST_NAME}:{LH_PORT}/{LH_CATALOG}/{LH_SCHEMA}",
   connect_args={
    'protocol': 'https', 
    'requests_kwargs': {'verify': ssl.CERT_NONE }
    }
)

# %%
## optional connection check (this may take several seconds)
with quick_engine.connect() as conn:
    df = pd.read_sql(
        sql='select * from tpch.tiny.customer limit 10',
        con=conn.connection
    )
df
# Out:
#    custkey                name                                address  \
# 0      376  Customer#000000376       4NwsvFQU T4mSgzvU1Rx2ZtHOGyaNyhe
# 1      377  Customer#000000377         PA4levhyD,Rvr0JHQ4QNOqJ9gW YXE
# 2      378  Customer#000000378  133stqM9 LT,a2BSlbm49 nXreFggaZgW6P6J
# 3      379  Customer#000000379                    t3QzCf,q1NbshmjOIUY
# 4      380  Customer#000000380       n2w3Jd1bipwICbOVgrELzcNRexmWSklo
# 5      381  Customer#000000381                       w3zVseYDbjBbzLld
# 6      382  Customer#000000382       UdgAMamK5JnSykA,ZPfR5W5zRFatDUye
# 7      383  Customer#000000383        iBIHYgXvVDpu6qq7FlqXVcAIDAzv4qs
# 8      384  Customer#000000384         kDDMb3ML nUSu2Sn7CUHyZVedAFUx9
# 9      385  Customer#000000385               zJvPI24TSPpiFzYfu3RvTKQ9
#
#    nationkey            phone  acctbal  mktsegment  \
# 0         16  26-437-952-8986  4231.45  AUTOMOBILE
# 1         23  33-260-610-4079  1043.72   MACHINERY
# 2         22  32-147-793-4825  5718.05    BUILDING
# 3          7  17-228-550-9246  5348.11  AUTOMOBILE
# 4         21  31-538-493-4229  2755.46    BUILDING
# 5          5  15-860-208-7093  9931.71    BUILDING
# 6          8  18-942-650-6657  6269.42  AUTOMOBILE
# 7          2  12-868-920-9034  -849.44   MACHINERY
# 8          9  19-271-453-8361  -614.30   HOUSEHOLD
# 9          3  13-741-675-6890  2457.09  AUTOMOBILE
#
#                                              comment
# 0  gs cajole quickly. bold asymptotes wake regula...
# 1  . slyly regular ideas cajole blithely. slyly i...
# 2           ackages haggle fluffily ironic packages.
# 3  l deposits cajole blithely blithely final depo...
# 4  riously special accounts. slyly final accounts...
# 5  t regular, bold accounts. carefully quick pack...
# 6  . blithely express notornis according to the b...
# 7  slyly express ideas haggle blithely unusual du...
# 8  olites. express, unusual dolphins cajole caref...
# 9  rs. blithely ironic deposits nag furiously acr...

# %% [markdown]
# ### Create Schema in watsonx.data Hive Bucket to store data

# %%
with quick_engine.connect() as conn:
    create_schema_result = pd.read_sql(sql="""
    CREATE SCHEMA hive_data.pratikmilvus WITH ( location = 's3a://hive-bucket/pratikmilvus')
    """,         
    con=conn.connection
)

# %%
# Create table 
with quick_engine.connect() as conn:
    create_table_result = pd.read_sql(sql="""
    CREATE TABLE hive_data.pratikmilvus.watsonwise
      (
      "id" varchar,
      "text" varchar,
      "title" varchar  )
     WITH (
     format = 'PARQUET',
     external_location = 's3a://hive-bucket/pratikmilvus'
     )     
    """,
    con=conn.connection
)

# %%
CHUNK_SIZE = 500
CHUNK_OVERLAP = 50
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=CHUNK_SIZE,
            chunk_overlap=CHUNK_OVERLAP
        )
texts = text_splitter.split_text(all_data)

# %%
# Insert data to watsonx.data
for index, i in enumerate(texts):
            
            chunk = texts[index].replace("'", "''").replace("%", "%%").replace("\n"," ")
            insert_stmt = f"insert into hive_data.pratikmilvus.watsonwise values ('{index+1}', '{chunk}', '{pdf}')"
            
            with quick_engine.connect() as connection:
                connection.execute(insert_stmt)
            print(f"{pdf} chunk {index+1} INSERTED")
print('Data inserted to watsonx.data')
# Out:
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 1 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 2 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 3 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 4 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 5 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 6 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 7 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 8 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 9 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 10 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 11 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 12 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 13 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 14 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 15 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 16 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 17 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 18 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 19 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 20 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 21 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 22 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 23 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 24 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 25 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 26 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 27 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 28 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 29 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 30 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 31 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 32 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 33 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 34 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 35 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 36 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 37 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 38 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 39 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 40 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 41 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 42 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 43 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 44 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 45 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 46 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 47 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 48 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 49 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 50 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 51 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 52 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 53 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 54 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 55 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 56 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 57 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 58 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 59 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 60 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 61 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 62 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 63 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 64 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 65 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 66 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 67 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 68 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 69 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 70 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 71 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 72 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 73 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 74 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 75 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 76 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 77 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 78 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 79 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 80 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 81 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 82 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 83 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 84 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 85 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 86 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 87 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 88 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 89 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 90 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 91 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 92 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 93 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 94 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 95 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 96 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 97 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 98 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 99 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 100 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 101 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 102 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 103 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 104 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 105 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 106 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 107 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 108 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 109 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 110 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 111 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 112 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 113 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 114 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 115 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 116 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 117 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 118 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 119 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 120 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 121 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 122 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 123 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 124 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 125 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 126 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 127 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 128 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 129 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 130 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 131 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 132 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 133 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 134 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 135 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 136 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 137 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 138 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 139 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 140 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 141 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 142 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 143 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 144 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 145 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 146 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 147 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 148 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 149 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 150 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 151 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 152 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 153 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 154 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 155 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 156 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 157 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 158 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 159 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 160 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 161 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 162 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 163 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 164 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 165 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 166 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 167 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 168 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 169 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 170 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 171 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 172 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 173 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 174 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 175 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 176 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 177 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 178 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 179 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 180 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 181 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 182 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 183 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 184 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 185 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 186 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 187 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 188 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 189 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 190 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 191 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 192 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 193 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 194 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 195 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 196 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 197 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 198 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 199 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 200 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 201 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 202 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 203 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 204 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 205 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 206 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 207 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 208 INSERTED
# /Users/pratiksinha/Desktop/milvus/watsonx_Value, Differentiators and Capabilities.pdf chunk 209 INSERTED
# Data inserted to watsonx.data

# %%
# confirm data inserted
with quick_engine.connect() as conn:
    articles = pd.read_sql(
        sql='select * from hive_data.pratikmilvus.watsonwise limit 10',
        con=conn.connection
    )
articles
# Out:
#     id                                               text  \
# 0   31  data in motion and at restFIPS 140-2 certified...
# 1   32  the month1. Start with a base instance for ste...
# 2  113  provides the most vector index types    to acc...
# 3   15  14Top Use-cases for Db2Warehouse on Cloud Reta...
# 4   97  search between the query vector and the vector...
# 5   55  editor and re-evaluate quickly and easilyRun S...
# 6   16  Cloud ArchitectureEnrichsensitiveon-premisesda...
# 7  114  knowledge, facts, and skills pluggable for LLM...
# 8   71  lakes  Run existing reporting and enable new A...
# 9   99  searches•The lower layers provide most of the ...
#
#                                                title
# 0  watsonx_Value, Differentiators and Capabilitie...
# 1  watsonx_Value, Differentiators and Capabilitie...
# 2  watsonx_Value, Differentiators and Capabilitie...
# 3  watsonx_Value, Differentiators and Capabilitie...
# 4  watsonx_Value, Differentiators and Capabilitie...
# 5  watsonx_Value, Differentiators and Capabilitie...
# 6  watsonx_Value, Differentiators and Capabilitie...
# 7  watsonx_Value, Differentiators and Capabilitie...
# 8  watsonx_Value, Differentiators and Capabilitie...
# 9  watsonx_Value, Differentiators and Capabilitie...

# %% [markdown]
# #### Load credentials for `ibm-watson-machine-learning`

# %%
import os
from dotenv import load_dotenv
from ibm_cloud_sdk_core import IAMTokenManager

load_dotenv('config.env')

# Connection variables
api_key = os.getenv("API_KEY", None)               #<your-ibm-cloud-api-key>
ibm_cloud_url = os.getenv("IBM_CLOUD_URL", None)   #<your-ibm-cloud-url>
project_id = os.getenv("PROJECT_ID", None)         #<your-watsonx.ai-project-id>
creds = {
    "url": ibm_cloud_url,
    "apikey": api_key 
}
access_token = IAMTokenManager(
    apikey = api_key,
    url = "https://iam.cloud.ibm.com/identity/token"
).get_token()

# %% [markdown]
# #### Create Lakehouse Connection
#
# We will use this watsonx.data connection to load the document.

# %%
import ssl
import urllib3
import os
from sqlalchemy import create_engine
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning) # disable https warning

LH_HOST_NAME=os.getenv("LH_HOST_NAME", None)
LH_PORT=os.getenv("LH_PORT", None) 
LH_USER=os.getenv("LH_USER", None)
LH_PW=os.getenv("LH_PW", None)
LH_CATALOG='tpch'
LH_SCHEMA='tiny'
LH_CERTFILE='cert.crt'

try: 
    quick_engine.dispose()
except:
    pass


quick_engine = create_engine(
   f"presto://{LH_USER}:{LH_PW}@{LH_HOST_NAME}:{LH_PORT}/{LH_CATALOG}/{LH_SCHEMA}",
   connect_args={
    'protocol': 'https', 
    'requests_kwargs': {'verify': f'{LH_CERTFILE}'}
    }
)

# %% [markdown]
# ## Load Vector Embeddings to Milvus
#
# Here we will take the data we loaded into watsonx.data from the previous step and load it into the vector database Milvus. This data was previously chunked and stored in a watsonx.data hive table, so we'll pull from here, vectorize the text chunks and load them into Milvus.
#
# Before we can start loading the data, though, we need to create a collection in Milvus to hold the data. We'll call this collection `watsonx`. This collection holds the vector embeddings for each chunk of text, as well as the original text itself and additional context.
#
# Let's get started!

# %% [markdown]
# #### Create Milvus Collection & Index
#
# Creating a Milvus collection involves first connecting to the Milvus server, then creating a collection with a defined schema and index.

# %%
from pymilvus import(
    Milvus,
    IndexType,
    Status,
    connections,
    FieldSchema,
    DataType,
    Collection,
    CollectionSchema,
)

import os 

host = os.getenv("MILVUS_HOST", None)
port = os.getenv("MILVUS_PORT", None)
password = 'password'
user = 'ibmlhadmin'
server_pem_path = 'cert.crt'

connections.connect(alias = 'default',
                   host = host,
                   port = port,
                   user = user,
                   password = password,
                   server_pem_path = server_pem_path,
                   server_name = 'watsonxdata',
                   secure = True)

# %%
# Create collection - define fields + schema

fields = [
    FieldSchema(name="id", dtype=DataType.INT64, is_primary=True, auto_id=True), # Primary key
    FieldSchema(name="article_text", dtype=DataType.VARCHAR, max_length=2500,),
    FieldSchema(name="article_title", dtype=DataType.VARCHAR, max_length=200,),
    FieldSchema(name="vector", dtype=DataType.FLOAT_VECTOR, dim=384),
]

schema = CollectionSchema(fields, "watsonx collection schema")

collection = Collection("pratikmilvus", schema)

# Create index
index_params = {
        'metric_type':'L2',
        'index_type':"IVF_FLAT",
        'params':{"nlist":2048}
}

collection.create_index(field_name="vector", index_params=index_params)
# Out:
# Status(code=0, message=)

# %%
## Status(code=0, message=) means success!

# %%
# we can run a check to see the collections in our milvus instance and we see if our collection has been created 

from pymilvus import utility
utility.list_collections()
# Out:
# ['pratik', 'watsonx', 'pratikmilvus']

# %% [markdown]
# #### Insert Vectors into Milvus
#
# Here we read data from the lakehouse table using the connection we created earlier. We pull text chunks and titles from the database, being sure to separate them out into separate lists. We then vectorize using the `sentence-transformers/all-MiniLM-L6-v2` sentence transformer model. Learn more about Hugging Face sentence transformers here: https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2
#
# It is important we assemble the article text, article titles and vector embeddings into a `data` object. This object will be used to load the data into Milvus.

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from pymilvus import Collection, connections
import warnings
warnings.filterwarnings('ignore')

# Download articles from watsonx.data using the engine we created earlier 
with quick_engine.connect() as conn:
    articles_df = pd.read_sql(
        sql='select * from hive_data.pratikmilvus.watsonwise',
        con=conn.connection
    )

# extract text + titles
passages = articles_df['text'].tolist()
passage_titles = articles_df['title'].tolist()

# Create vector embeddings + data
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2') # 384 dim
passage_embeddings = model.encode(passages)

basic_collection = Collection("pratikmilvus") 
data = [
    passages,
    passage_titles,
    passage_embeddings
]
out = basic_collection.insert(data)
basic_collection.flush()  # Ensures data persistence

# %%
## check to ensure entities have been loaded into the collection

basic_collection = Collection("pratikmilvus") 
basic_collection.num_entities
# Out:
# 210

# %% [markdown]
# ## Query Milvus & Prompt LLM

# %% [markdown]
# After gathering the data from document and then vectorizing it and inserting into Milvus, we are now ready to perform queries against the vector database. We will use the same `sentence-transformers/all-MiniLM-L6-v2` model to generate the query vector and then use Milvus to find the most similar vectors in the database.

# %% [markdown]
# #### Load Milvus Collection

# %%
# Load collection
basic_collection = Collection("pratikmilvus")      
basic_collection.load()

# Query function
def query_milvus(query, num_results=5):
    
    # Vectorize query
    model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2') # 384 dim
    query_embeddings = model.encode([query])

    # Search
    search_params = {
        "metric_type": "L2", 
        "params": {"nprobe": 5}
    }
    results = basic_collection.search(
        data=query_embeddings, 
        anns_field="vector", 
        param=search_params,
        limit=num_results,
        expr=None, 
        output_fields=['article_text'],
    )
    return results

# %% [markdown]
# #### Prompt LLM with Query Results

# %%
#Prompt questions for Query results
question_text = "List some core functionalities of watsonx.data in 500 words?"
#question_text = " Explain watsonx.data in 1000 words? "

# %%
# Query Milvus 

num_results = 3
results = query_milvus(question_text, num_results)

relevant_chunks = []
for i in range(num_results):    
    #print(f"id: {results[0].ids[i]}")
    #print(f"distance: {results[0].distances[i]}")
    text = results[0][i].entity.get('article_text')
    relevant_chunks.append(text)
    
#print(relevant_chunks)

# %%
def make_prompt(context, question_text):
    return (f"{context}\n\nPlease answer a question using this text. "
          + f"If the question is unanswerable, say \"unanswerable\"."
          + f"\n\nQuestion: {question_text}")


# Build prompt w/ Milvus results
# Embed retrieved passages(context) and user question into into prompt text

context = "\n\n".join(relevant_chunks)
prompt = make_prompt(context, question_text)

# %%
print(prompt)
# Out:
# come after GAwatsonx.data CapabilitiesAI/ML at scaleBuild, train, tune, deploy, and monitor trusted AI/ML models for mission critical workloads with data in watsonx.data and ensure compliance with lineage and reproducibility of data used for AI.E.g., Presto and Spark ensure an open lakehouse architectureStreamline data engineeringReduce data pipelines, simplify data transformation, and enrich data for consumption using SQL, Python, or an AI infused conversational interface.E.g., insights
#
# infused conversational interface.E.g., insights powered by generative AI through the power of watsonx.ai foundation models giving you the capability to span the AI lifecycle.Real-time analytics & BICombine data from existing sources with new data in watsonx.datato unlock new, faster insights without the cost and complexity of duplicating and moving data across different environments.E.g., such as Parquet, Avro, Apache ORC while leveragingApache Iceberg table format and shared metadata to share
#
# x Scale and accelerate the impact of AI with trusted data. Leverage governed enterprise data in watsonx.data  to seamlessly train or fine-tune foundation modelsLeverage foundation models to automate data  search, discovery, and linking in watsonx.data  Enable fine-tuned models to be managed through market  leading governance and lifecycle management capabilities Scale AI workloads, for  all your data, anywhereTrain, validate, tune and  deploy AI modelsEnable responsible, transparent and
#
# Please answer a question using this text. If the question is unanswerable, say "unanswerable".
#
# Question: List some core functionalities of watsonx.data in 500 words?

# %%
from ibm_watson_machine_learning.foundation_models import Model
from ibm_watson_machine_learning.metanames import GenTextParamsMetaNames as GenParams

# Model Parameters
params = {
        GenParams.DECODING_METHOD: "greedy",
        GenParams.MIN_NEW_TOKENS: 1,
        GenParams.MAX_NEW_TOKENS: 1000,
        GenParams.TEMPERATURE: 0.5,
}
model = Model(
        model_id='ibm/granite-13b-chat-v2', 
        params=params, credentials=creds, 
        project_id=project_id
)

# Prompt LLM
response = model.generate_text(prompt)
print(f"Question: {question_text}{response}")
# Out:
# Question: List some core functionalities of watsonx.data in 500 words?
#
# Watsonx.data is a platform that offers a wide range of functionalities for managing and analyzing data, enabling organizations to build, train, and deploy trusted AI/ML models. Here are some of the core functionalities of watsonx.data:
#
# 1. Open lakehouse architecture: Watsonx.data supports an open lakehouse architecture, which allows organizations to store, manage, and analyze all their data in a single, scalable platform. This architecture combines the best of data warehousing and data lakes, providing a unified view of both structured and unstructured data.
# 2. SQL, Python, and AI-infused conversational interface: Watsonx.data offers a SQL interface for querying data, as well as Python and AI-infused conversational interfaces for data exploration and analysis. This flexibility enables data scientists, analysts, and other users to choose the most suitable tool for their needs, whether it's a traditional SQL query or a more interactive, AI-powered interface.
# 3. Data engineering and data pipelines: Watsonx.data simplifies data engineering tasks by reducing data pipelines, simplifying data transformation, and enriching data for consumption. This functionality helps organizations to streamline their data processing and ensure that their data is ready for analysis and modeling.
# 4. Real-time analytics and BI: Watsonx.data combines data from existing sources with new data in watsonx.data to unlock new, faster insights. This functionality enables organizations to make more informed decisions by analyzing data in real-time, without the need to move or duplicate data across different environments.
# 5. Data governance and lifecycle management: Watsonx.data provides robust data governance and lifecycle management capabilities, ensuring that data is managed and used responsibly and transparently. This functionality helps organizations to meet regulatory requirements and maintain the trust of their stakeholders.
# 6. Foundation models: Watsonx.data enables organizations to train or fine-tune foundation models using trusted data from watsonx.data. This functionality allows organizations to automate data search, discovery, and linking, and leverage foundation models to unlock new insights and capabilities.
# 7. Responsible AI: Watsonx.data is designed to ensure that AI models are built and deployed responsibly, with a focus on fairness, transparency, and accountability. This functionality helps organizations to build trust with their stakeholders and ensure that their AI models are aligned with their values and goals.
#
# In summary, Watsonx.data offers a wide range of functionalities for managing and analyzing data, enabling organizations to build, train, and deploy trusted AI/ML models. From an open lakehouse architecture to real-time analytics and foundation models, Watsonx.data provides the tools and capabilities needed to unlock the value of their data and drive better decision-making.
